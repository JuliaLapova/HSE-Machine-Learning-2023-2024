# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 19.09.2023
#
# Мягкий дедлайн: 23:59MSK 02.10.2023
#
# Жесткий дедлайн: 23:59MSK 06.10.2023

# %% [markdown]
# #Начальная информация

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки pandas и визуализации с помощью matplotlib. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после жёсткого дедлайна нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате homework-practice-01-pandas-Username.ipynb, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: xx.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# Ячейка с неразмеченным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
# your code
15/2
# Out:
# 7.5

# %% [markdown]
# Мой текст

# %%
15 // 2
# Out:
# 7

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидете много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно =)

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в pandas — это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %% [markdown]
# #Начало заданий

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <span style="color:red">Перед выполнением задания необходимо ознакомиться с первым семинаром (seminars/sem01-pandas.ipynb) </span>.
#
# Это поможет вам получить общее понимание происходяшего и успешнее справиться с заданием.
#
# Также успешному выполнению способствует внимательное чтение текста задания от начала до конца.
#
# Удачи!

# %% [markdown]
# Скачаем подготовленные на семинаре данные:

# %%
# !wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
# !powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
# import wget
# wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки. Использование <code>vectorize</code> и  <code>apply</code>, <code>apply_along_axis</code> крайне нежелательно.

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
# your code
df = pd.read_excel('/content/end_seminar.xlsx')
df.tail(10)
# Out:
#                   timestamp                                id  rating  \
# 351 2020-05-18 23:58:33.903  8fe79f84f36e3a5d2d6745621321302c    1016
# 352 2020-05-18 23:59:20.831  f93afd8e92c336b471aa3bbbc579aefe    1298
# 353 2020-05-18 23:59:28.998  9963fc00d9405a35b894cc04a7e19855    1135
# 354 2020-05-19 08:55:39.509  98c5a2548d93f26bd4195466e93178b3    1035
# 355 2020-05-19 18:58:06.283  ba298cbd9be59b84bab33325e956f27e    1155
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# 351       NaN    NaN                 Безопасность компьютерных систем
# ...

# %%
# Посмотрим общую информацию о датафрейме
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      361 non-null    datetime64[ns]
#  1   id             361 non-null    object
#  2   rating         361 non-null    int64
#  3   18_group       223 non-null    float64
#  4   is_mi          18 non-null     float64
#  5   fall_1         361 non-null    object
#  6   fall_2         361 non-null    object
#  7   fall_3         361 non-null    object
#  8   spring_1       361 non-null    object
#  9   spring_2       361 non-null    object
#  10  spring_3       361 non-null    object
#  11  is_first_time  359 non-null    object
#  12  percentile     361 non-null    float64
#  13  17_group       138 non-null    float64
#  14  blended        138 non-null    object
#  15  is_ml_student  57 non-null     float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(9)
# ...

# %% [markdown]
# #### 2. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
# посчитаем именно пустые значения
df.isnull().sum()
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых (постарайтесь избежать перечисления названий всех столбцов).

# %%
# Булевы и числовые колонки заполняем нулями
df[df.select_dtypes(include=['int64', 'float64']).columns] = df[df.select_dtypes(include=['int64', 'float64']).columns].fillna(0)

# Объектные колонки заполняем пустой строкой
df[df.select_dtypes(include=['object']).columns] = df[df.select_dtypes(include=['object']).columns].fillna('')

# %%
# Проверим что не осталось пропусков
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      361 non-null    datetime64[ns]
#  1   id             361 non-null    object
#  2   rating         361 non-null    int64
#  3   18_group       361 non-null    float64
#  4   is_mi          361 non-null    float64
#  5   fall_1         361 non-null    object
#  6   fall_2         361 non-null    object
#  7   fall_3         361 non-null    object
#  8   spring_1       361 non-null    object
#  9   spring_2       361 non-null    object
#  10  spring_3       361 non-null    object
#  11  is_first_time  361 non-null    object
#  12  percentile     361 non-null    float64
#  13  17_group       361 non-null    float64
#  14  blended        361 non-null    object
#  15  is_ml_student  361 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(9)
# ...

# %%
df.tail()
# Out:
#                   timestamp                                id  rating  \
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# 356       0.0    0.0                      Statistical Learning Theory
# 357       0.0    0.0                Анализ неструктурированных данных
# 358       0.0    0.0  Сбор и обработка данных с помощью краудсорсинга
# 359       0.0    0.0                 Безопасность компьютерных систем
# 360       0.0    0.0                Анализ неструктурированных данных
#
#                                                 fall_2  \
# 356                  Анализ неструктурированных данных
# ...

# %% [markdown]
# #### 3. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Есть ли в ней ответы "Нет"? Сколько их?
#
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию. В дальнейших заданиях используйте версию данных без повторов.
#
# <i>Обращения со значением "Нет" в 'is_first_time' могут быть как повторными, так и первичными, поскольку поле заполняли сами студенты.</i>

# %%
# Проверим, сколько раз в колонке 'is_first_time' встречается значение "Нет"
not_first_time = df[df['is_first_time'] == 'Нет'].shape[0]
print(f'Ответ "Нет" встречается в колонке is_first_time {not_first_time} раз.')
# Out:
# Ответ "Нет" встречается в колонке is_first_time 51 раз.

# %%
# Отсортируем по 'id' и 'timestamp' и оставим последнюю запись каждого студента
df_sorted = df.sort_values(['id', 'timestamp'])
df_no_duplicates = df_sorted.drop_duplicates('id', keep='last')

# Проверим, что не осталось дупликатов
duplicates = df_no_duplicates['id'].duplicated().sum()
print(f'Повторы встречаются в колонке id {duplicates} раз.')
# Out:
# Повторы встречаются в колонке id 0 раз.

# %%
# Обновим датафрейм, чтобы в дальнейшем уже использовать датафрейм без дубликатов но с коротким называнием.
df = df_no_duplicates.copy()
print(len(df))
# Out:
# 347

# %% [markdown]
# #### 4. [0.5 балла] Ответьте на вопросы:
# 1. Сколько было заявок из групп 18-го года набора, а сколько из групп 17-го года?
# 2. Есть ли студенты с равными перцентилями (среди объединенных данных, ведь конкурс на каждый курс общий)?

# %%
# Посмотрим
group_18_count = df['18_group'].ne(0).sum()
group_17_count = df['17_group'].ne(0).sum()

print(f'Было {group_18_count} заявок из группы 18-го года набора.')
print(f'Было {group_17_count} заявок из группы 17-го года набора.')

duplicates_persents = df['percentile'].duplicated().sum()
duplicates_persents_r = df['rating'].duplicated().sum()

print(f'Повторы встречаются в колонке persentile {duplicates_persents} раз.')
print(f'Повторы встречаются в колонке rating {duplicates_persents_r} раз.')


no_overlap = (df['17_group'].ne(0) & df['18_group'].ne(0)).all()
print(f'Пересекаются ли ненулевые значения в 17_group и 18_group? {no_overlap}')
# Out:
# Было 213 заявок из группы 18-го года набора.
# Было 134 заявок из группы 17-го года набора.
# Повторы встречаются в колонке persentile 1 раз.
# Повторы встречаются в колонке rating 0 раз.
# Пересекаются ли ненулевые значения в 17_group и 18_group? False

# %% [markdown]
# #### 5. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из blended-курсов собрались студенты с самым высоким средним рейтингом (выведите этот курс и количество студентов на нем)?

# %%
# Сначала посмотрим какие бывают blended-курсы
blended_courses = df[df["17_group"] != 0]["blended"].unique()
print(f'Существуют следующие blended курсы для четверокурсников:')
print('\n'.join(blended_courses))
# Out:
# Существуют следующие blended курсы для четверокурсников:
# Соревновательный анализ данных
# DevOps
# Введение в дифференциальную геометрию

# %%
# Отфильтруйте df так, чтобы включить только те строки, где 'blended' не равно нулю
#filtered_df = df[df['blended'] != 0]
filtered_df = df[df["17_group"] != 0]

# подсчет записей для каждого курса
course_counts = filtered_df.groupby('blended').size()

#course_counts.info()

# поиск курса с наибольшим количеством записей
most_popular_course = course_counts.idxmax()

# поиск курса с наибольшим количеством записей
most_popular_course_value = course_counts.max()

# вывод результатов
print('Самый популярный курс:', most_popular_course)
print('Количество студентов:', course_counts[most_popular_course]) # Здесь дописать код под максимум
# Out:
# Самый популярный курс: DevOps
# Количество студентов: 87

# %%
filtered_df.groupby('blended').count()[['id']]
# Out:
#                                        id
# blended
# DevOps                                 87
# Введение в дифференциальную геометрию  15
# Соревновательный анализ данных         32

# %%
filtered_df[filtered_df['blended'] != ''].groupby(by='blended').mean(numeric_only=True)[['rating']].sort_values(by='rating', ascending=False)
# Out:
#                                             rating
# blended
# Введение в дифференциальную геометрию  1210.733333
# DevOps                                 1154.172414
# Соревновательный анализ данных         1144.218750

# %%
print(f'Курс, на который собрались студенты с самым высоким рейтингом и средний рейтинг, приведены в таблице ниже:')

filtered_df[filtered_df['blended'] != ''].groupby(by='blended').mean(numeric_only=True)[['rating']].sort_values(by='rating', ascending=False).head(1)
# Out:
# Курс, на который собрались студенты с самым высоким рейтингом и средний рейтинг, приведены в таблице ниже:
#                                             rating
# blended
# Введение в дифференциальную геометрию  1210.733333

# %% [markdown]
# #### 6. [1 балл] Выясните, есть ли студенты с абсолютно одинаковыми предпочтениями по всем курсам.
#
# Для этого сформируйте таблицу, где для каждого возможного набора курсов посчитано количество студентов, выбравших такой набор, и оставьте только строки где это количество больше 1.
#
# В данном случае набор курсов задается упорядоченным множеством ('fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'). Элемент blended будет нулевым для 3-го курса.

# %%
# your code
df_same = df.copy()
df_same['courses'] = df[['fall_1','fall_2','fall_3','spring_1','spring_2','spring_3','blended']].apply(tuple, axis=1)
duplicated_rows = df_same[df_same.duplicated(['courses'])]

duplicated_courses = df_same.groupby('courses').count()[['id']]
courses_more_than_1 = duplicated_courses.loc[duplicated_courses['id'] > 1]


print(f'Ниже приведены надоры курсов, которые были выбраны более чем 1 студентом. Всего таких наборов {len(courses_more_than_1)} штук.')

courses_more_than_1
# Out:
# Ниже приведены надоры курсов, которые были выбраны более чем 1 студентом. Всего таких наборов 15 штук.
#                                                     id
# courses
# (Statistical Learning Theory, Анализ неструктур...   2
# (Байесовские методы машинного обучения, Анализ ...   2
# (Байесовские методы машинного обучения, Анализ ...   2
# (Безопасность компьютерных систем, Statistical ...   3
# (Безопасность компьютерных систем, Высокопроизв...   2
# (Безопасность компьютерных систем, Высокопроизв...   3
# (Безопасность компьютерных систем, Высокопроизв...   2
# (Безопасность компьютерных систем, Матричные вы...   2
# (Безопасность компьютерных систем, Сбор и обраб...   2
# (Безопасность компьютерных систем, Теория баз д...   2
# (Высокопроизводительные вычисления, Безопасност...   2
# (Высокопроизводительные вычисления, Сбор и обра...   2
# (Моделирование временных рядов, Сбор и обработк...   2
# (Сбор и обработка данных с помощью краудсорсинг...   2
# ...

# %% [markdown]
# #### 7. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
# Разобъем датафрейм на две части. При этом будем проверять чтобы значения не были NaN и также не были равны 0.
df_3rd_year = df[(df['18_group'].notnull()) & (df['18_group'] != 0)].copy()
df_4th_year = df[(df['17_group'].notnull()) & (df['17_group'] != 0)].copy()

# Объедим все выбранные курсы в одном столбце для каждого из датафреймов
df_3rd_year['all_courses'] = df_3rd_year[['fall_1','fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']].stack().reset_index(drop=True)
df_4th_year['all_courses'] = df_4th_year[['fall_1','fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']].stack().reset_index(drop=True)

# Получим список уникальных курсов для 3-курсников и для 4-курсников
courses_3rd_year = df_3rd_year['all_courses'].unique()
courses_4th_year = df_4th_year['all_courses'].unique()

# Найдем общие для обоих групп курсы
common_courses = list(set(courses_3rd_year).intersection(courses_4th_year))

print('Курсы общие для студентов 18-го года набора и для студентов 17-го года набора:')
common_courses
# Out:
# Курсы общие для студентов 18-го года набора и для студентов 17-го года набора:
# ['Численные методы',
#  'Безопасность компьютерных систем',
#  'Моделирование временных рядов',
#  'Statistical Learning Theory',
#  'Сбор и обработка данных с помощью краудсорсинга',
#  'Высокопроизводительные вычисления']

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 18-го года и только студентам 17-го года.

# %%
# Получаем множества из выбранных курсов
set_3rd_year = set(df_3rd_year['all_courses'])
set_4th_year = set(df_4th_year['all_courses'])

# Находим курсы, которые предлагались только студентам 3-го курса
only_3rd_year = set_3rd_year.difference(set_4th_year)

# Находим курсы, которые предлагались только студентам 4-го курса
only_4th_year = set_4th_year.difference(set_3rd_year)

# %%
print('курсы, которые предлагались только студентам 3-го курса:')
only_3rd_year
# Out:
# курсы, которые предлагались только студентам 3-го курса:
# {'',
#  'Анализ данных в бизнесе',
#  'Дискретная оптимизация',
#  'Дополнительные главы прикладной статистики',
#  'Компьютерные сети',
#  'Матричные вычисления',
#  'Машинное обучение 2',
#  'Принятие решений в условиях риска и неопределённости',
#  'Промышленное программирование на языке Java',
#  'Системы баз данных',
#  'Теория баз данных',
#  'Язык SQL'}

# %%
print('курсы, которые предлагались только студентам 4-го курса:')
only_4th_year
# Out:
# курсы, которые предлагались только студентам 4-го курса:
# {'DevOps',
#  'Анализ неструктурированных данных',
#  'Байесовские методы машинного обучения',
#  'Введение в дифференциальную геометрию',
#  'Генеративные модели в машинном обучении',
#  'Глубинное обучение в обработке звука',
#  'Компьютерное зрение',
#  'Конфликты и кооперация',
#  'Методы сжатия и передачи медиаданных',
#  'Обучение с подкреплением',
#  'Проектирование и разработка высоконагруженных сервисов',
#  'Символьные вычисления',
#  'Соревновательный анализ данных'}

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.
#
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html) (обычно сокращается до sns). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
#
# **5 пунктов после которых ваши графики не будут прежними:**
# - для красивой картинки <code>%config InlineBackend.figure_format = 'retina'</code>
# - задаем размер (почти) всех графиков (можно выбрать другие значения) <code>plt.rcParams['figure.figsize'] = 8, 5</code>
# - размер шрифта подписей графиков <code>plt.rcParams['font.size'] = 12</code>
# - формат в котором сохраняется изображение <code>mpl.rcParams['savefig.format'] = 'pdf'</code>
# - sns – seaborn, добавляет решетку <code>sns.set_style('darkgrid')</code>
#
# Добавьте эти функции в ячейку ниже. Каждый график все равно придется настраивать отдельно, но указанные строчки позволят значительно упростить процесс.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns


# your code
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 8, 5
plt.rcParams['font.size'] = 12
mpl.rcParams['savefig.format'] = 'pdf'
sns.set_style('darkgrid')

# %% [markdown]
# #### 8. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
# Создадим датафрейм с колонкой timestamp как индекс
df_rating = df.set_index('timestamp')

# Группировка данных по дням и расчет среднего рейтинга
df_rating_daily = df_rating.resample('D').mean(numeric_only=True)['rating']

# Устанавливаем размер подписей
plt.rcParams['xtick.labelsize'] = 8

# Создаем график
plt.bar(df_rating_daily.index, df_rating_daily.values)

# Форматируем подписи по оси X
plt.xticks(df_rating_daily.index, df_rating_daily.index.strftime('%Y-%m-%d'), rotation=45)

plt.title("Средние рейтинги по дням")
plt.xlabel("Дата")
plt.ylabel("Средний рейтинг")

# Сохраним график в pdf
plt.savefig("average_ratings.pdf")

plt.show()

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# <span style="color:red">!!!ВНИМАТЕЛЬНО ИЗУЧИТЕ ТЕКСТ НИЖЕ!!!</span>.
#
# <span style="color:orange">Если во время выполнения заданий у вас вознинут вопросы -- еще раз перечитайте текст целиком, скорее всего ответы уже содержатся в нем.</span>

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# Алгоритм распределения студентов по курсам:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом и еще не прошел на необходимое количество курсов. Места заполняются лучшими по перцентилю рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# Обращаем ваше внимание на следующие детали:
# - Конкурс на каждый курс общий для 3-го и 4-го курса
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса. <i>Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — <code>fall_1</code> и <code>fall_2</code>, второй приоритет — <code>fall_3</code>. Такие студенты участвуют только в двух волнах отбора</i>.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2. **Если студент специализации МОП выбрал Машинное обучение 2, то его приоритеты сдвигаются.** Из-за совпадений первого и второго курса по выбору двигать приоритеты не надо.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Заведомо известно, что в процессе распределения не возникнет ситуации, когда на одно место претендуют студенты с одинаковым перцентилем.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно. <i>Допустимо итерироваться по <b>курсам</b>, на которые проводится отбор, и по <b>волнам</b> отбора. Если вы придумаете, как обойтись и без этих циклов, то на усмотрение проверяющего могут быть добавлены бонусные баллы. <b>Дублирование кода не признается успешным избавлением от циклов</b></i>
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * Три колонки: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Если студент должен выбрать два курса по выбору, то порядок в колонках course1 и course2 не важен.
#
#     * hint: для сохранения воспользуйтесь df.to_csv('solution.csv', index=None)
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * У студентов 18-го года номера групп соответствуют номерам до распределения по специализациям. Это означает, что по номеру группы 18* нельзя однозначно определить специализацию студента. При этом в рамках распределения важно знать информацию только о двух из них: МОП и МИ. Эти знание можно получить из колонок 'is_ml_student
# ' и 'is_mi' соответственно.
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
assert df.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert df.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
# !pip install openpyxl

# %%
# (￣^￣)ゞ
df = df_no_duplicates.copy()

df.loc[:, 'num_courses_to_choose'] = 1

# Меняем значения на 2 по условию
df.loc[(df['17_group'] == 172) |
       (df['17_group'] == 173) |
#       (df['is_ml_student'] == 1) |
       (df['is_mi'] == 1), 'num_courses_to_choose'] = 2

# %%
df.to_excel('students_df_2.xlsx', engine='openpyxl')

# %%
df.to_excel('data_1.xlsx', engine='openpyxl')

# %% [markdown]
# Проверка:

# %%
col_name = 'num_courses_to_choose'    # insert your new column name as str

assert(df[df['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert(df[df['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert(df[df['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert(df[df['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
unique_courses = {k: None for k in data['fall_1'].unique()}
unique_courses

courses_60 = ['Statistical Learning Theory', 'Высокопроизводительные вычисления', 'Анализ неструктурированных данных']
unique_courses = {k: 60 if k in courses_60 else 30 for k in data['fall_1'].unique()}
unique_courses
# Out:
# {'Безопасность компьютерных систем': 30,
#  'Сбор и обработка данных с помощью краудсорсинга': 30,
#  'Анализ неструктурированных данных': 60,
#  'Теория баз данных': 30,
#  'Высокопроизводительные вычисления': 60,
#  'Матричные вычисления': 30,
#  'Язык SQL': 30,
#  'Statistical Learning Theory': 60,
#  'Глубинное обучение в обработке звука': 30,
#  'Моделирование временных рядов': 30,
#  'Байесовские методы машинного обучения': 30,
#  'Принятие решений в условиях риска и неопределённости': 30}

# %%
courses_students = {k: sorted(list(zip(data.loc[data['fall_1'] == k, 'id'], data.loc[data['fall_1'] == k, 'percentile'])), key=lambda x: x[1]) for k in data['fall_1'].unique()}
courses_students
# Out:
# {'Безопасность компьютерных систем': [('3e106aaef8b24dbb01319c73e14c2936',
#    0.0),
#   ('bfe75c08c6b7e31d4e7d48c9c5fed69b', 0.02242152466367708),
#   ('04f9a2dd035a040318ecd064959df3a0', 0.02690582959641252),
#   ('bb29d9b9230528a4873f91abce2095b8', 0.03623188405797106),
#   ('e5fb2c5a9d8a09915b15d14bf6cf3174', 0.04035874439461884),
#   ('d37fe725a8ee1d1b263463baf7560fd4', 0.05381165919282516),
#   ('f3cc62fabaa597e8fe0b20ac2e6f46d3', 0.05829596412556048),
#   ('447a377d20b3181f0436c72c19a48c37', 0.06278026905829592),
#   ('67e3336ac46b6030f7b25853154783c6', 0.06726457399103136),
#   ('b6fcd3cdcbbd950b4207acb65ee12d03', 0.0717488789237668),
#   ('594c54bb30547b44c9cc617aa2754f10', 0.07246376811594202),
#   ('bb9bbd259ab6b8170a7dc6fb35695d13', 0.08695652173913049),
#   ('b3eb1cdc4beffbdd5b29a8d54d649bc0', 0.094170403587444),
#   ('4add93dff84a52a0b3d690f07aa081d4', 0.09865470852017932),
#   ('4df9699d2022802f80b3e6426d6976d7', 0.1086956521739131),
# ...

# %%
courses_students = {
    k: sorted(
        # Это исходный список студентов
        list(zip(data.loc[data['fall_1'] == k, 'id'], data.loc[data['fall_1'] == k, 'percentile'])) +
        # Это добавление новых студентов
        list(zip(
            data.loc[(data['fall_2'] == k) & (data['num_courses_to_choose'] == 2), 'id'],
            data.loc[(data['fall_2'] == k) & (data['num_courses_to_choose'] == 2), 'percentile']
        )),
        key=lambda x: x[1]
    ) for k in data['fall_1'].append(data['fall_2']).unique()
}
# Out:
# <ipython-input-65-84bfef177d90>:11: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ) for k in data['fall_1'].append(data['fall_2']).unique()

# %%
courses_students = {
    k: sorted(
        list(zip(data.loc[data['fall_1'] == k, 'id'], data.loc[data['fall_1'] == k, 'percentile'])) +
        list(zip(
            data.loc[(data['fall_2'] == k) & (data['num_courses_to_choose'] == 2), 'id'],
            data.loc[(data['fall_2'] == k) & (data['num_courses_to_choose'] == 2), 'percentile']
        )),
        key=lambda x: x[1])
    for k in pd.concat([data['fall_1'], data['fall_2']]).unique()}

# %%
courses_students
# Out:
# {'Безопасность компьютерных систем': [('3e106aaef8b24dbb01319c73e14c2936',
#    0.0),
#   ('bfe75c08c6b7e31d4e7d48c9c5fed69b', 0.02242152466367708),
#   ('04f9a2dd035a040318ecd064959df3a0', 0.02690582959641252),
#   ('bb29d9b9230528a4873f91abce2095b8', 0.03623188405797106),
#   ('e5fb2c5a9d8a09915b15d14bf6cf3174', 0.04035874439461884),
#   ('d37fe725a8ee1d1b263463baf7560fd4', 0.05381165919282516),
#   ('f3cc62fabaa597e8fe0b20ac2e6f46d3', 0.05829596412556048),
#   ('447a377d20b3181f0436c72c19a48c37', 0.06278026905829592),
#   ('67e3336ac46b6030f7b25853154783c6', 0.06726457399103136),
#   ('b6fcd3cdcbbd950b4207acb65ee12d03', 0.0717488789237668),
#   ('594c54bb30547b44c9cc617aa2754f10', 0.07246376811594202),
#   ('bb9bbd259ab6b8170a7dc6fb35695d13', 0.08695652173913049),
#   ('b3eb1cdc4beffbdd5b29a8d54d649bc0', 0.094170403587444),
#   ('4add93dff84a52a0b3d690f07aa081d4', 0.09865470852017932),
#   ('4df9699d2022802f80b3e6426d6976d7', 0.1086956521739131),
# ...

# %%
first_values = {k: next(iter(v), None) for k, v in courses_students.items()}
first_values
# Out:
# {'Безопасность компьютерных систем': ('3e106aaef8b24dbb01319c73e14c2936', 0.0),
#  'Сбор и обработка данных с помощью краудсорсинга': ('86d929f6fd741e56e93cee5900298849',
#   0.008968609865470878),
#  'Анализ неструктурированных данных': ('7f98e4487c7a910567f2d841e5e764c3',
#   0.05072463768115942),
#  'Теория баз данных': ('651f2fa7d270b436246ddd7d05880bfa', 0.0358744394618834),
#  'Высокопроизводительные вычисления': ('7fe7df0d207babbf30249b3063ac1f26',
#   0.007246376811594235),
#  'Матричные вычисления': ('e0ca1a9548af9a3f98428c62420aa484',
#   0.004484304932735439),
#  'Язык SQL': ('93ff79a51cd602f1dd3028ba2c129503', 0.1838565022421524),
#  'Statistical Learning Theory': ('3a7326c9e355a67d3805824ca34c4bc5', 0.0),
#  'Глубинное обучение в обработке звука': ('6a93fcbc79d0df6ddeba3b46739fc3d8',
#   0.07971014492753625),
#  'Моделирование временных рядов': ('ff549c331d45453052f28ad2614afda9',
#   0.1076233183856502),
# ...

# %%
data = df.copy()

students_count = {}

for index, row in data.iterrows():
    if row.num_courses_to_choose == 2:
        if row.fall_1 not in students_count:
            students_count[row.fall_1] = []
        if row.fall_2 not in students_count:
            students_count[row.fall_2] = []

        students_count[row.fall_1].append((row.id, row.percentile))
        students_count[row.fall_2].append((row.id, row.percentile))
    else:
        if row.fall_1 not in students_count:
            students_count[row.fall_1] = []

        students_count[row.fall_1].append((row.id, row.percentile))

# %%
courses_60 = ['Statistical Learning Theory', 'Высокопроизводительные вычисления', 'Анализ неструктурированных данных']

for course in students_count:
    # если курс находится в списке courses_60
    if course in courses_60:
        students_count[course] = sorted(students_count[course], key=lambda x: x[1], reverse=False)[:60]

    # иначе
    else:
        students_count[course] = sorted(students_count[course], key=lambda x: x[1], reverse=False)[:30]

# %%
students_count
# Out:
# {'Безопасность компьютерных систем': [('3e106aaef8b24dbb01319c73e14c2936',
#    0.0),
#   ('bfe75c08c6b7e31d4e7d48c9c5fed69b', 0.02242152466367708),
#   ('04f9a2dd035a040318ecd064959df3a0', 0.02690582959641252),
#   ('bb29d9b9230528a4873f91abce2095b8', 0.03623188405797106),
#   ('e5fb2c5a9d8a09915b15d14bf6cf3174', 0.04035874439461884),
#   ('d37fe725a8ee1d1b263463baf7560fd4', 0.05381165919282516),
#   ('f3cc62fabaa597e8fe0b20ac2e6f46d3', 0.05829596412556048),
#   ('447a377d20b3181f0436c72c19a48c37', 0.06278026905829592),
#   ('67e3336ac46b6030f7b25853154783c6', 0.06726457399103136),
#   ('b6fcd3cdcbbd950b4207acb65ee12d03', 0.0717488789237668),
#   ('594c54bb30547b44c9cc617aa2754f10', 0.07246376811594202),
#   ('bb9bbd259ab6b8170a7dc6fb35695d13', 0.08695652173913049),
#   ('b3eb1cdc4beffbdd5b29a8d54d649bc0', 0.094170403587444),
#   ('4add93dff84a52a0b3d690f07aa081d4', 0.09865470852017932),
#   ('4df9699d2022802f80b3e6426d6976d7', 0.1086956521739131),
# ...

# %%
first_values = {k: next(iter(v), None) for k, v in courses_students.items()}
print(len(first_values))
first_values
# Out:
# 12
# {'Безопасность компьютерных систем': ('3e106aaef8b24dbb01319c73e14c2936', 0.0),
#  'Сбор и обработка данных с помощью краудсорсинга': ('86d929f6fd741e56e93cee5900298849',
#   0.008968609865470878),
#  'Анализ неструктурированных данных': ('7f98e4487c7a910567f2d841e5e764c3',
#   0.05072463768115942),
#  'Теория баз данных': ('651f2fa7d270b436246ddd7d05880bfa', 0.0358744394618834),
#  'Высокопроизводительные вычисления': ('3a7326c9e355a67d3805824ca34c4bc5',
#   0.0),
#  'Матричные вычисления': ('e0ca1a9548af9a3f98428c62420aa484',
#   0.004484304932735439),
#  'Язык SQL': ('93ff79a51cd602f1dd3028ba2c129503', 0.1838565022421524),
#  'Statistical Learning Theory': ('3a7326c9e355a67d3805824ca34c4bc5', 0.0),
#  'Глубинное обучение в обработке звука': ('6a93fcbc79d0df6ddeba3b46739fc3d8',
#   0.07971014492753625),
#  'Моделирование временных рядов': ('dc7f705ae386b0457542a833571d51d0',
#   0.04347826086956519),
# ...

# %%
# Создаем пустой словарь с ключом id
chosen_courses = {row.id: [] for _, row in data.iterrows()}
#chosen_courses

#Заполним словарь chosen_courses курсами которые выбрали студенты
for course in students_count:
    for student_id, _ in students_count[course]:
        if len(chosen_courses[student_id]) < data.loc[data.id == student_id, 'num_courses_to_choose'].values[0]:
            chosen_courses[student_id].append(course)


import pandas as pd

df_chosen_courses = pd.DataFrame.from_dict(chosen_courses, orient='index')
df_chosen_courses.to_excel('chosen_courses.xlsx', engine='openpyxl')

# %%
chosen_df = pd.DataFrame(chosen_courses.items(), columns=['id', 'course'])
chosen_df[['course1','course2']] = pd.DataFrame(chosen_df.course.tolist(), index= chosen_df.index)
chosen_df = chosen_df.drop(columns=['course'])
chosen_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       347 non-null    object
#  1   course1  269 non-null    object
#  2   course2  39 non-null     object
# dtypes: object(3)
# memory usage: 8.3+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 347 entries, 161 to 139
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   timestamp              347 non-null    datetime64[ns]
#  1   id                     347 non-null    object
#  2   rating                 347 non-null    int64
#  3   18_group               347 non-null    float64
#  4   is_mi                  347 non-null    float64
#  5   fall_1                 347 non-null    object
#  6   fall_2                 347 non-null    object
#  7   fall_3                 347 non-null    object
#  8   spring_1               347 non-null    object
#  9   spring_2               347 non-null    object
#  10  spring_3               347 non-null    object
#  11  is_first_time          347 non-null    object
#  12  percentile             347 non-null    float64
#  13  17_group               347 non-null    float64
# ...

# %%
# Обновляем DataFrame с выбранными курсами каждым студентом
data = pd.merge(data, chosen_df, on='id')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 347 entries, 0 to 346
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   timestamp              347 non-null    datetime64[ns]
#  1   id                     347 non-null    object
#  2   rating                 347 non-null    int64
#  3   18_group               347 non-null    float64
#  4   is_mi                  347 non-null    float64
#  5   fall_1                 347 non-null    object
#  6   fall_2                 347 non-null    object
#  7   fall_3                 347 non-null    object
#  8   spring_1               347 non-null    object
#  9   spring_2               347 non-null    object
#  10  spring_3               347 non-null    object
#  11  is_first_time          347 non-null    object
#  12  percentile             347 non-null    float64
#  13  17_group               347 non-null    float64
# ...

# %%
data.to_excel('data_before_check.xlsx', engine='openpyxl')

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
# !wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0'
check_df = pd.read_csv('2_task_check.csv')

# %%
check_df.to_excel('2_task_check.xlsx', engine='openpyxl')

# %%
check_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       347 non-null    object
#  1   id              347 non-null    object
#  2   rating          347 non-null    int64
#  3   18_group        347 non-null    float64
#  4   is_mi           347 non-null    float64
#  5   fall_1          347 non-null    object
#  6   fall_2          347 non-null    object
#  7   fall_3          347 non-null    object
#  8   spring_1        347 non-null    object
#  9   spring_2        347 non-null    object
#  10  spring_3        347 non-null    object
#  11  is_first_time   345 non-null    object
#  12  percentile      347 non-null    float64
#  13  17_group        347 non-null    float64
#  14  blended         134 non-null    object
#  15  is_ml_student   347 non-null    float64
#  16  is_first_place  10 non-null     object
# ...

# %%
min_percentile_students = {course: min(students, key=lambda x: x[1]) for course, students in students_count.items()}

# %%
min_percentile_students
# Out:
# {'Безопасность компьютерных систем': ('3e106aaef8b24dbb01319c73e14c2936', 0.0),
#  'Сбор и обработка данных с помощью краудсорсинга': ('86d929f6fd741e56e93cee5900298849',
#   0.008968609865470878),
#  'Анализ неструктурированных данных': ('7f98e4487c7a910567f2d841e5e764c3',
#   0.05072463768115942),
#  'Теория баз данных': ('651f2fa7d270b436246ddd7d05880bfa', 0.0358744394618834),
#  'Высокопроизводительные вычисления': ('3a7326c9e355a67d3805824ca34c4bc5',
#   0.0),
#  'Матричные вычисления': ('e0ca1a9548af9a3f98428c62420aa484',
#   0.004484304932735439),
#  'Язык SQL': ('93ff79a51cd602f1dd3028ba2c129503', 0.1838565022421524),
#  'Statistical Learning Theory': ('3a7326c9e355a67d3805824ca34c4bc5', 0.0),
#  'Глубинное обучение в обработке звука': ('6a93fcbc79d0df6ddeba3b46739fc3d8',
#   0.07971014492753625),
#  'Байесовские методы машинного обучения': ('67e4ec4fe5c0601815692fbd6d403fb7',
#   0.01449275362318836),
#  'Моделирование временных рядов': ('dc7f705ae386b0457542a833571d51d0',
# ...

# %%
len(min_percentile_students)
# Out:
# 12

# %%
max_percentile_students = {course: max(students, key=lambda x: x[1]) for course, students in students_count.items()}

# %%
len(max_percentile_students)
# Out:
# 12

# %%
max_percentile_students
# Out:
# {'Безопасность компьютерных систем': ('081eba3952cfc116e0e9b941d6a974a2',
#   0.2152466367713004),
#  'Сбор и обработка данных с помощью краудсорсинга': ('cef24632489091cb8c085688b7d78dec',
#   0.7173913043478262),
#  'Анализ неструктурированных данных': ('d539461bf254cf8b3201cdf7990b119e',
#   0.9927536231884058),
#  'Теория баз данных': ('bb94ed5af639819dac15574197c80da3', 0.9237668161434978),
#  'Высокопроизводительные вычисления': ('b4f1f195bd1bc63490a7bc42275a71cd',
#   0.9192825112107623),
#  'Матричные вычисления': ('d9f0e5ebc6718202b86eaee2de1c697b',
#   0.9327354260089686),
#  'Язык SQL': ('feb53dcdd28fff9dc4a981c3419fea6f', 0.968609865470852),
#  'Statistical Learning Theory': ('af20596134e83f3ca61259b325aa9688',
#   0.9730941704035875),
#  'Глубинное обучение в обработке звука': ('d555d2805e1d93d4f023e57dc4c8f403',
#   0.9637681159420289),
#  'Байесовские методы машинного обучения': ('98c5a2548d93f26bd4195466e93178b3',
#   0.9057971014492754),
# ...

# %%
max_percentile_students_dict = {key[0]: key[1] for key in max_percentile_students.values()}
max_percentile_students_dict
# Out:
# {'081eba3952cfc116e0e9b941d6a974a2': 0.2152466367713004,
#  'cef24632489091cb8c085688b7d78dec': 0.7173913043478262,
#  'd539461bf254cf8b3201cdf7990b119e': 0.9927536231884058,
#  'bb94ed5af639819dac15574197c80da3': 0.9237668161434978,
#  'b4f1f195bd1bc63490a7bc42275a71cd': 0.9192825112107623,
#  'd9f0e5ebc6718202b86eaee2de1c697b': 0.9327354260089686,
#  'feb53dcdd28fff9dc4a981c3419fea6f': 0.968609865470852,
#  'af20596134e83f3ca61259b325aa9688': 0.9730941704035875,
#  'd555d2805e1d93d4f023e57dc4c8f403': 0.9637681159420289,
#  '98c5a2548d93f26bd4195466e93178b3': 0.9057971014492754,
#  'c1e88502b6673d22c38ee1352e3a1dd9': 0.9710144927536232,
#  '7a21ef645ecb42198be493dd65320e78': 0.9955156950672646}

# %%
min_percentile_students_dict = {key[0]: key[1] for key in min_percentile_students.values()}
min_percentile_students_dict
# Out:
# {'3e106aaef8b24dbb01319c73e14c2936': 0.0,
#  '86d929f6fd741e56e93cee5900298849': 0.008968609865470878,
#  '7f98e4487c7a910567f2d841e5e764c3': 0.05072463768115942,
#  '651f2fa7d270b436246ddd7d05880bfa': 0.0358744394618834,
#  '3a7326c9e355a67d3805824ca34c4bc5': 0.0,
#  'e0ca1a9548af9a3f98428c62420aa484': 0.004484304932735439,
#  '93ff79a51cd602f1dd3028ba2c129503': 0.1838565022421524,
#  '6a93fcbc79d0df6ddeba3b46739fc3d8': 0.07971014492753625,
#  '67e4ec4fe5c0601815692fbd6d403fb7': 0.01449275362318836,
#  'dc7f705ae386b0457542a833571d51d0': 0.04347826086956519,
#  '701078e1e897399f675e96bdda5fb149': 0.4753363228699552}

# %%
min_percentile_students_dict = {key[0]: True for key in min_percentile_students.values()}
data['is_first_place'] = data['id'].map(min_percentile_students_dict)

# %%
max_percentile_students_dict = {key[0]: True for key in max_percentile_students.values()}
data['is_last_place'] = data['id'].map(max_percentile_students_dict)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 347 entries, 0 to 346
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   timestamp              347 non-null    datetime64[ns]
#  1   id                     347 non-null    object
#  2   rating                 347 non-null    int64
#  3   18_group               347 non-null    float64
#  4   is_mi                  347 non-null    float64
#  5   fall_1                 347 non-null    object
#  6   fall_2                 347 non-null    object
#  7   fall_3                 347 non-null    object
#  8   spring_1               347 non-null    object
#  9   spring_2               347 non-null    object
#  10  spring_3               347 non-null    object
#  11  is_first_time          347 non-null    object
#  12  percentile             347 non-null    float64
#  13  17_group               347 non-null    float64
# ...

# %%
df = data.copy()

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
#df = merged_df.copy()

# %%
df = data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 347 entries, 0 to 346
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   timestamp              347 non-null    datetime64[ns]
#  1   id                     347 non-null    object
#  2   rating                 347 non-null    int64
#  3   18_group               347 non-null    float64
#  4   is_mi                  347 non-null    float64
#  5   fall_1                 347 non-null    object
#  6   fall_2                 347 non-null    object
#  7   fall_3                 347 non-null    object
#  8   spring_1               347 non-null    object
#  9   spring_2               347 non-null    object
#  10  spring_3               347 non-null    object
#  11  is_first_time          347 non-null    object
#  12  percentile             347 non-null    float64
#  13  17_group               347 non-null    float64
# ...

# %%
fir_col_name = 'is_first_place'       # insert name of your new column with is_first_place as str
last_col_name = 'is_last_place'     # insert name of your new column with is_last_place as str


assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ==
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-009f25886c53> in <cell line: 5>()
#       3
#       4
# ----> 5 assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#       6         ==
#       7         check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __eq__(self, other)
#      40     @unpack_zerodim_and_defer("__eq__")
#      41     def __eq__(self, other):
# ---> 42         return self._cmp_method(other, operator.eq)
#      43
# ...

# %% [markdown]
# #### 3. [3 балла] Проведите все три волны отбора студентов на курсы по выбору

# %%
# (￣^￣)ゞ

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (https://contest.yandex.ru/contest/52663/problems/A/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# *Дисклеймер:*
#
# Успешная посылка в контесте является **обязательным** условием получения полного балла за этот (и следующий) пункт. Если добиться успешной посылки не удастся, баллы будут выставляться на усмотрение проверяюшего.
#
# При этом ОК в контесте не гарантирует полный балл. Оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# **Дополнительное задание. [2 бонусных балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.**
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %%
# (￣^'￣)ゞ

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (https://contest.yandex.ru/contest/52663/problems/A) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:
